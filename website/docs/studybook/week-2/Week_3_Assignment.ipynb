# %% [markdown]
# # Week 3 Assignment
#
# 도란보리 소모임 3주차 과제입니다. 이번 과제는 퀴즈 형식으로 진행됩니다.

# %% [markdown]
# #### 1. 마르코프 가정이 성립한다는 조건이 사후확률 $\text{Pr}(X_{t+1} | X_t, \dots, X_1)$ 에 어떤 영향을 주는가? 다음 중 가장 정확한 설명을 고르시오.
# 1. $X_{t-1}, \dots X_1$은 $X_{t+1}$의 분포에 일부 영향을 주지만 감소한다.
# 2. $X_{t+1}$는 오직 $X_t$의 값만으로 조건부 독립된다.
# 3. $X_{t+1}$는 모든 과거 상태와 완전한 독립이다.
# 4. $X_{t+1}$는 $X_{t}$보다 $X_{t-1}$의 영향을 더 많이 받는다.

# %% [markdown]
# #### 2. DTMC와 DTMP의 차이로 옳은 것은?
#
# 1. DTMC는 이산 상태만 가능하고, DTMP는 연속 상태도 가능하다.
# 2. DTMC는 연속 시간, DTMP는 이산 시간이다.
# 3. DTMC가 DTMP의 상위 개념이다.
# 4. 두 모델은 수학적으로 완전히 같다.

# %% [markdown]
# #### 3. 다음 중 양자화 과정의 핵심 목적으로 가장 적절한 것은?
#
# 1. 데이터의 분산을 줄여 평균을 높인다.
# 2. 연속 데이터를 이산적 대표값으로 압축한다.
# 3. 확률 분포를 변경하지 않고 그대로 유지한다.
# 4. 상태 간 전이를 제거한다.

# %% [markdown]
# #### 4. 다음 행렬 $P$가 마르코프 전이 행렬이 될 수 없는 이유는?
#
# $$P=
# \begin{bmatrix}
# 0.2 & 0.8 & 0.1 \\
# 0.3 & 0.5 & 0.2 \\
# 0.4 & 0.6 & 0.1
# \end{bmatrix}
# $$
#
# 1. 대각행렬이 아니다.
# 2. 어떤 행의 합이 $1$이 아니다
# 3. 어떤 열의 합이 $1$이 아니다
# 4. 비대칭이다

# %% [markdown]
# #### 5. 상태 $1$에 대해, $1\rightarrow 1$의 전이 확률이 $0$인 DTMC에서, 상태 $1$이 정상 분포에서 양수 확률을 가질 수 있는가?
#
# 1. 항상 가능
# 2. 항상 불가능
# 3. 경우에 따라 가능
# 4. 초기 분포에 따라 가능

# %% [markdown]
# #### 6. 다음 전이 행렬의 정상 분포 $\pi$를 구하시오.
#
# $$
# P=
# \begin{bmatrix}
# 0.5 & 0.5 \\
# 0.2 & 0.8
# \end{bmatrix}
# $$

# %% [markdown]
# #### 7. 정상분포 $\pi$를 구할 때 고윳값 $\lambda=1$을 사용하는 이유는 무엇인가? 가장 정확한 설명을 고르시오.
#
# 1. $1$은 모든 확률의 합이기 때문이다.
# 2. $\lambda=1$인 고윳값만 분포가 변하지 않기 때문이다.
# 3. $\lambda=1$이 가장 작은 고윳값이기 때문이다.
# 4. 다른 고윳값은 항상 복소수이기 때문이다.

# %% [markdown]
# #### 8. 다음과 같는 상태 전이 그래프를 갖는 DTMC의 기약성에 대한 서술로 옳은 것은? (단, 모든 화살표는 100% 전이를 의미)
#
# ```mermaid
# stateDiagram
#   A --> B
#   B --> C
#   C --> A
#   D --> D
# ```
#
# 1. 기약적
# 2. 비기약적
# 3. 상태 A, B, C만 고려하면 기약적
# 4. 상태 D는 기약적, 나머지는 비기약적

# %% [markdown]
# #### 9. 아래 전이가 있을 때 상태 A의 주기성으로 옳은 것은?
#
# $$
# \left\{
# \begin{aligned}
# A \rightarrow A : 0.2 \\
# A \rightarrow B : 0.8 \\
# B \rightarrow A : 1.0
# \end{aligned}
# \right.
# $$
#
# 1. 주기가 $2$이다.
# 2. 주기가 $1$이다.
# 3. 비주기적이다.
# 4. 판별할 수 없다.

# %% [markdown]
# #### 10. 마르코프 체인이 기약적이지만 주기적이면 어떤 일이 발생하는가?
#
# 1. 정상분포로 수렴한다
# 2. 진동하며 수렴하지 않는다
# 3. 발산한다
# 4. 확률이 0과 1을 반복한다

# %% [markdown]
# #### 11. 다음과 같은 전이 행렬을 갖는 DTMC의 정상 분포 $\pi$가 존재하는가?
#
# $$
# P=
# \begin{bmatrix}
# 1 & 0 \\
# 0.3 & 0.7
# \end{bmatrix}
# $$
#
# 1. 존재하며 $\pi = (1,0)$
# 2. 존재하며 $\pi = (0.3, 0.7)$
# 3. 존재하지 않는다
# 4. $\pi$는 초기 상태에 따라 달라진다

# %% [markdown]
# #### 12. 연속 상태를 3개의 코드북으로 양자화했는데, 실제 데이터 분포가 매우 복잡한 다봉형(multimodal) 분포였다. 이 경우 양자화의 문제점으로 가장 적절한 것은?
#
# 1. DTMC의 기약성이 사라진다.
# 2. 정상 분포가 존재하지 않는다.
# 3. 중요한 정보가 손실될 수 있다.
# 4. 전이 확률이 0이 된다.

# %% [markdown]
# #### 13. 정상 분포가 $\pi = (0.6,~0.3,~0.1)$일 때 올바른 해석은?
#
# 1. 가장 최근 상태만 $0.6$의 확률로 $1$이다.
# 2. 매우 오래 후에는 $1$에서 시작할 확률이 $0.6$이다.
# 3. $t \rightarrow \infty$일 때 상태 $1$에 있을 비율은 $0.6$이다.
# 4. 전체 데이터 중 $60\%$가 상태 $1$로 양자화된다.

# %% [markdown]
# #### 14. 어떤 DTMC에서 정상분포 $\pi$가 존재한다. 아래 중 반드시 참인 것은?
#
# 1. 체인은 기약적이다.
# 2. 체인은 비주기적이다.
# 3. 체인은 에르고딕성을 가진다.
# 4. 체인은 적어도 하나의 닫힌 집합을 가진다.
