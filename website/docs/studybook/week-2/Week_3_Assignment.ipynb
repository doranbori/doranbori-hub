# %% [markdown]
# **Week 3 Assignment**
#
# 도란보리 소모임 3주차 과제입니다. 이번 과제는 퀴즈 형식으로 진행됩니다.

# %% [markdown]
# 1. 마르코프 가정이 성립한다는 조건이 사후확률(Pr(Xₜ₊₁ | Xₜ, …)) 에 어떤 영향을 주는가? 다음 중 가장 정확한 설명을 고르시오.
# A) Xₜ₋₁,… X₁은 Xₜ₊₁의 분포에 일부 영향을 주지만 감소한다.
# B) Xₜ₊₁는 오직 Xₜ의 값만으로 조건부 독립된다.
# C) Xₜ₊₁는 모든 과거 상태와 완전한 독립이다.
# D) Xₜ₊₁는 Xₜ보다 Xₜ₋₁의 영향을 더 많이 받는다.

# %% [markdown]
# 2. DTMC와 DTMP의 차이로 옳은 것은?
#  A) DTMC는 이산 상태만 가능하고, DTMP는 연속 상태도 가능하다.
#  B) DTMC는 연속 시간, DTMP는 이산 시간이다.
#  C) DTMC가 DTMP의 상위 개념이다.
#  D) 두 모델은 수학적으로 완전히 같다.

# %% [markdown]
# 3. 다음 중 양자화 과정의 핵심 목적으로 가장 적절한 것은?
#  A) 데이터의 분산을 줄여 평균을 높인다.
#  B) 연속 데이터를 이산적 대표값으로 압축한다.
#  C) 확률 분포를 변경하지 않고 그대로 유지한다.
#  D) 상태 간 전이를 제거한다.

# %% [markdown]
# 4. 다음 행렬 P가 마르코프 전이 행렬이 될 수 없는 이유는?
#
# P=[ 0.2 0.8 0.1
# 0.3 0.5 0.2
# 0.4 0.6 0.1 ]
#
#   A) 대각행렬이 아니다.
#   B) 어떤 행의 합이 1이 아니다
#   C) 어떤 열의 합이 1이 아니다
#   D) 비대칭이다

# %% [markdown]
# 5. 상태 1→1 전이 확률이 0인 DTMC에서, 상태 1이 정상 분포에서 양수 확률을 가질 수 있는가?
#  A) 항상 가능
#  B) 항상 불가능
#  C) 경우에 따라 가능
#  D) 초기 분포에 따라 가능

# %% [markdown]
# 6. 다음 전이 행렬의 정상 분포 π를 구하시오.
# P=[ 0.5 0.5
#       0.2 0.8 ]

# %% [markdown]
# 7. 정상분포 π를 구할 때 고윳값 λ=1을 사용하는 이유는 무엇인가? 가장 정확한 설명을 고르시오.
# A) 1은 모든 확률의 합이기 때문이다.
# B) λ=1인 고윳값만 분포가 변하지 않기 때문이다.
# C) λ=1이 가장 작은 고윳값이기 때문이다.
# D) 다른 고윳값은 항상 복소수이기 때문이다.

# %% [markdown]
# 8. 다음 그래프의 DTMC는 기약적인가? (모든 화살표는 100% 전이를 의미)
#    ┌→ B → C ┐
#    │  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  │&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       D → D
#    └─ A ←─┘
#  A) 기약적
#  B) 비기약적
#  C) 상태 A,B,C만 고려하면 기약적
#  D) 상태 D는 기약적, 나머지는 비기약적

# %% [markdown]
# 9. 아래 전이가 있을 때 상태 A는 비주기적인가?
# *A → A : 0.2
# *A → B : 0.8
# *B → A : 1.0
#
# A) 주기성 2
# B) 주기성 1
# C) 비주기적
# D) 판별할 수 없다

# %% [markdown]
# 10. 마르코프 체인이 기약적이지만 주기적이면 어떤 일이 발생하는가?
# A) 정상분포로 수렴한다
# B) 진동하며 수렴하지 않는다
# C) 발산한다
# D) 확률이 0과 1을 반복한다

# %% [markdown]
# 11. 다음 전이 행렬이 있다.
# 𝑃=[1 0
# 0.3 0.7]
# 이 DTMC의 정상분포 π는 존재하는가?
#
# A) 존재하며 π = (1,0)
# B) 존재하며 π = (0.3,0.7)
# C) 존재하지 않는다
# D) π는 초기 상태에 따라 달라진다

# %% [markdown]
# 12. 연속 상태를 3개의 코드북으로 양자화했는데, 실제 데이터 분포가 매우 복잡한 다봉형(multimodal) 분포였다. 이 경우 양자화의 문제점으로 가장 적절한 것은?
#
# A) DTMC의 기약성이 사라진다
# B) 정상 분포가 존재하지 않는다
# C) 중요한 정보가 손실될 수 있다
# D) 전이 확률이 0이 된다

# %% [markdown]
# 13. 정상 분포가 π = (0.6, 0.3, 0.1)일 때 올바른 해석은?
#
# A) 가장 최근 상태만 0.6의 확률로 1이다.
# B) 매우 오래 후에는 1에서 시작할 확률이 0.6이다.
# C) t → ∞일 때 상태 1에 있을 비율은 0.6이다.
# D) 전체 데이터 중 60%가 상태 1로 양자화된다.

# %% [markdown]
# 14. 어떤 DTMC에서 정상분포 π가 존재한다. 아래 중 반드시 참인 것은?
#
# A) 체인은 기약적이다
# B) 체인은 비주기적이다
# C) 체인은 에르고딕성을 가진다
# D) 체인은 적어도 하나의 닫힌 집합을 가진다
